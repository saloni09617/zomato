# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading dataset

# %%
restaurants=pd.read_csv("zomato.csv" ,encoding = "ISO-8859-1")
countrycode=pd.read_excel("Country-Code.xlsx")

# %%
restaurants.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# # Data Cleaning

# %%
restaurants['Average Cost for two']=restaurants['Average Cost for two'].replace(0,np.nan)

# %%
restaurants.dropna(inplace=True)

# %% [markdown]
# # 1) Merge the country sheet and Zomato file to get the country code

# %%
restaurants=restaurants.merge(countrycode,on='Country Code')

# %%
restaurants.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# # list all the country to do analysis on each one

# %%
indiaRes=restaurants[restaurants['Country']=='India']
singaporeRes=restaurants[restaurants['Country']=='Singapore']
AusRes=restaurants[restaurants['Country']=='Australia']
BrazRes=restaurants[restaurants['Country']=='Brazil']
CanadaRes=restaurants[restaurants['Country']=='Canada']
UAERes=restaurants[restaurants['Country']=='UAE']
UKRes=restaurants[restaurants['Country']=='United Kingdom']
USRes=restaurants[restaurants['Country']=='United States']

# %%
indiaRes.head()
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 609        3400025                             Jahanpanah             1  Agra
# 610        3400341                    Rangrezz Restaurant             1  Agra
# 611        3400005                Time2Eat - Mama Chicken             1  Agra
# 612        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 613        3400017                         Pinch Of Spice             1  Agra
#
#                                                Address     Locality  \
# 609  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 610  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 611        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 612  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 613  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# ...

# %% [markdown]
# Get the cities

# %% [markdown]
# Get the top restaurants in each city(On the basis of ratings and votes)

# %%
indiaRes.City.value_counts()
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Amritsar          21
# Bhubaneshwar      21
# Guwahati          21
# Lucknow           21
# Mangalore         20
# Mumbai            20
# Mysore            20
# Nagpur            20
# Kochi             20
# Nashik            20
# Patna             20
# Puducherry        20
# Pune              20
# Ranchi            20
# Surat             20
# Vadodara          20
# Ludhiana          20
# Vizag             20
# Kolkata           20
# Aurangabad        20
# Jaipur            20
# Indore            20
# Goa               20
# Coimbatore        20
# Chennai           20
# Bhopal            20
# Bangalore         20
# Dehradun          19
# Allahabad         19
# Varanasi          18
# Hyderabad         18
# Kanpur            18
# Chandigarh        18
# Agra              17
# Secunderabad       2
# Mohali             1
# Panchkula          1
# ...

# %% [markdown]
# # 2) Top restaurant in delhi based on the rating and vote count

# %%
DelhiTopRes=indiaRes[(indiaRes['City']=='New Delhi')&(indiaRes['Aggregate rating']>4.5)][['Aggregate rating','Restaurant Name','Votes']].sort_values(ascending=False,by='Votes')

# %%
DelhiTopRes.style.apply(lambda x: ['background: yellow' if x.name == 'Votes' else 'background: pink' for i in x])
# Out:
# <style type="text/css">
# #T_a5600_row0_col0, #T_a5600_row0_col1, #T_a5600_row1_col0, #T_a5600_row1_col1, #T_a5600_row2_col0, #T_a5600_row2_col1, #T_a5600_row3_col0, #T_a5600_row3_col1, #T_a5600_row4_col0, #T_a5600_row4_col1, #T_a5600_row5_col0, #T_a5600_row5_col1, #T_a5600_row6_col0, #T_a5600_row6_col1, #T_a5600_row7_col0, #T_a5600_row7_col1, #T_a5600_row8_col0, #T_a5600_row8_col1, #T_a5600_row9_col0, #T_a5600_row9_col1, #T_a5600_row10_col0, #T_a5600_row10_col1, #T_a5600_row11_col0, #T_a5600_row11_col1, #T_a5600_row12_col0, #T_a5600_row12_col1, #T_a5600_row13_col0, #T_a5600_row13_col1, #T_a5600_row14_col0, #T_a5600_row14_col1, #T_a5600_row15_col0, #T_a5600_row15_col1, #T_a5600_row16_col0, #T_a5600_row16_col1 {
#   background: pink;
# }
# ...

# %%
singaporeRes.head()
# Out:
#      Restaurant ID       Restaurant Name  Country Code       City  \
# 529       18483372             Sky On 57           184  Singapore
# 530       18484349  Cut By Wolfgang Puck           184  Singapore
# 531       18496057      Restaurant Andre           184  Singapore
# 532       18483389      Potato Head Folk           184  Singapore
# 533       18483222                  Jaan           184  Singapore
#
#                                               Address  \
# 529    10 Bayfront Avenue, 57 Marina Bay Sands 018956
# 530  2 Bayfront Avenue, B1-71 Marina Bay Sands 018972
# 531                        41 Bukit Pasoh Road 089855
# 532                         36 Keong Saik Road 089143
# 533  2 Stamford Road, Level 70 Equinox Complex 178882
#
#                             Locality  \
# 529   Bayfront Avenue, Downtown Core
# 530  Bayfront Subzone, Downtown Core
# 531          Cantonment Road, Outram
# 532                Chinatown, Outram
# 533         City Hall, Downtown Core
#
# ...

# %%
singaporeRes.City.value_counts()
# Out:
# Singapore    20
# Name: City, dtype: int64

# %% [markdown]
# # 3) Finding out relationship between the rating and votes

# %%
sns.jointplot(x='Votes',y='Aggregate rating',data=DelhiTopRes)

# %% [markdown]
# # 4) No of restaurants in each country

# %%
India=indiaRes['Restaurant Name'].nunique()
India
# Out:
# 6595

# %%
Singapore=singaporeRes['Restaurant Name'].nunique()
Singapore
# Out:
# 20

# %%
Australia=AusRes['Restaurant Name'].nunique()
Australia
# Out:
# 24

# %%
Brazil=BrazRes['Restaurant Name'].nunique()
Brazil
# Out:
# 58

# %%
Canada=CanadaRes['Restaurant Name'].nunique()
Canada
# Out:
# 4

# %%
UAE=UAERes['Restaurant Name'].nunique()
UAE
# Out:
# 55

# %%
UK=UKRes['Restaurant Name'].nunique()
UK
# Out:
# 74

# %%
US=USRes['Restaurant Name'].nunique()
US
# Out:
# 408

# %% [markdown]
# # 5) Top 5 restaurants with online delivery

# %%
DelhiTopResOnline=indiaRes[(indiaRes['City']=='New Delhi') & (indiaRes['Aggregate rating']>4.5) & (indiaRes['Has Online delivery']=='Yes')][['Aggregate rating','Restaurant Name','Votes']].sort_values(ascending=False,by='Votes').head(5)

# %%
DelhiTopResOnline.style.apply(lambda x: ['background: yellow' if x.name == 'Has Online delivery' else 'background: pink' for i in x])
# Out:
# <style type="text/css">
# #T_07acb_row0_col0, #T_07acb_row0_col1, #T_07acb_row0_col2, #T_07acb_row1_col0, #T_07acb_row1_col1, #T_07acb_row1_col2, #T_07acb_row2_col0, #T_07acb_row2_col1, #T_07acb_row2_col2, #T_07acb_row3_col0, #T_07acb_row3_col1, #T_07acb_row3_col2, #T_07acb_row4_col0, #T_07acb_row4_col1, #T_07acb_row4_col2 {
#   background: pink;
# }
# </style>
# <table id="T_07acb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07acb_level0_col0" class="col_heading level0 col0" >Aggregate rating</th>
#       <th id="T_07acb_level0_col1" class="col_heading level0 col1" >Restaurant Name</th>
#       <th id="T_07acb_level0_col2" class="col_heading level0 col2" >Votes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07acb_level0_row0" class="row_heading level0 row0" >2991</th>
#       <td id="T_07acb_row0_col0" class="data row0 col0" >4.900000</td>
# ...

# %%
GurgaonTopResOnline=indiaRes[(indiaRes['City']=='Gurgaon')&(indiaRes['Aggregate rating']>4.5)&(indiaRes['Has Online delivery']=='Yes')][['Aggregate rating','Restaurant Name','Votes']].sort_values(ascending=False,by='Votes').head(5)

# %%
GurgaonTopResOnline.style.apply(lambda x: ['background: yellow' if x.name == 'Has Online delivery' else 'background: pink' for i in x])
# Out:
# <style type="text/css">
# #T_f31d9_row0_col0, #T_f31d9_row0_col1, #T_f31d9_row0_col2, #T_f31d9_row1_col0, #T_f31d9_row1_col1, #T_f31d9_row1_col2, #T_f31d9_row2_col0, #T_f31d9_row2_col1, #T_f31d9_row2_col2 {
#   background: pink;
# }
# </style>
# <table id="T_f31d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f31d9_level0_col0" class="col_heading level0 col0" >Aggregate rating</th>
#       <th id="T_f31d9_level0_col1" class="col_heading level0 col1" >Restaurant Name</th>
#       <th id="T_f31d9_level0_col2" class="col_heading level0 col2" >Votes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f31d9_level0_row0" class="row_heading level0 row0" >1292</th>
#       <td id="T_f31d9_row0_col0" class="data row0 col0" >4.600000</td>
#       <td id="T_f31d9_row0_col1" class="data row0 col1" >Twigly</td>
#       <td id="T_f31d9_row0_col2" class="data row0 col2" >395</td>
#     </tr>
#     <tr>
# ...

# %%
NoidaTopResOnline=indiaRes[(indiaRes['City']=='Noida')&(indiaRes['Aggregate rating']>3)&(indiaRes['Has Online delivery']=='Yes')][['Aggregate rating','Restaurant Name','Votes']].sort_values(ascending=False,by='Votes').head(5)

# %%
NoidaTopResOnline.style.apply(lambda x: ['background: yellow' if x.name == 'Has Online delivery' else 'background: pink' for i in x])
# Out:
# <style type="text/css">
# #T_e03c4_row0_col0, #T_e03c4_row0_col1, #T_e03c4_row0_col2, #T_e03c4_row1_col0, #T_e03c4_row1_col1, #T_e03c4_row1_col2, #T_e03c4_row2_col0, #T_e03c4_row2_col1, #T_e03c4_row2_col2, #T_e03c4_row3_col0, #T_e03c4_row3_col1, #T_e03c4_row3_col2, #T_e03c4_row4_col0, #T_e03c4_row4_col1, #T_e03c4_row4_col2 {
#   background: pink;
# }
# </style>
# <table id="T_e03c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e03c4_level0_col0" class="col_heading level0 col0" >Aggregate rating</th>
#       <th id="T_e03c4_level0_col1" class="col_heading level0 col1" >Restaurant Name</th>
#       <th id="T_e03c4_level0_col2" class="col_heading level0 col2" >Votes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e03c4_level0_row0" class="row_heading level0 row0" >8412</th>
#       <td id="T_e03c4_row0_col0" class="data row0 col0" >3.800000</td>
#       <td id="T_e03c4_row0_col1" class="data row0 col1" >Desi Vibes</td>
# ...

# %% [markdown]
# # 6) Cheap but best restaurants available in the city

# %%
Chennai=indiaRes[(indiaRes['City']=='Chennai')&(indiaRes['Aggregate rating']>4.5)&(indiaRes['Votes']>500)][['Average Cost for two','Aggregate rating','Votes']].sort_values(ascending=True,by='Votes')

# %%
Chennai.style.apply(lambda x: ['background: darkorange' if x.name == 'Average Cost for two' else 'background: lightsteelblue' for i in x])
# Out:
# <style type="text/css">
# #T_a9a9c_row0_col0, #T_a9a9c_row1_col0, #T_a9a9c_row2_col0, #T_a9a9c_row3_col0, #T_a9a9c_row4_col0 {
#   background: darkorange;
# }
# #T_a9a9c_row0_col1, #T_a9a9c_row0_col2, #T_a9a9c_row1_col1, #T_a9a9c_row1_col2, #T_a9a9c_row2_col1, #T_a9a9c_row2_col2, #T_a9a9c_row3_col1, #T_a9a9c_row3_col2, #T_a9a9c_row4_col1, #T_a9a9c_row4_col2 {
#   background: lightsteelblue;
# }
# </style>
# <table id="T_a9a9c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9a9c_level0_col0" class="col_heading level0 col0" >Average Cost for two</th>
#       <th id="T_a9a9c_level0_col1" class="col_heading level0 col1" >Aggregate rating</th>
#       <th id="T_a9a9c_level0_col2" class="col_heading level0 col2" >Votes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9a9c_level0_row0" class="row_heading level0 row0" >803</th>
#       <td id="T_a9a9c_row0_col0" class="data row0 col0" >1600.000000</td>
# ...

# %% [markdown]
# # 7) Top cuisines in each region

# %%
IndianCuisines=restaurants[restaurants['Country']=='India']['Cuisines'].value_counts().head()

# %% [markdown]
# # 8) Aggregate rating of all restaurants in each city in a country

# %%
table=pd.pivot_table(data=restaurants,index = ('Country','City'),values='Aggregate rating')

# %%
cm=sns.light_palette("pink",as_cmap=True)
table.style.background_gradient(cmap=cm,axis=0)
# Out:
# <style type="text/css">
# #T_117ee_row0_col0, #T_117ee_row5_col0, #T_117ee_row12_col0, #T_117ee_row23_col0, #T_117ee_row60_col0, #T_117ee_row71_col0 {
#   background-color: #f9d6dc;
#   color: #000000;
# }
# #T_117ee_row1_col0, #T_117ee_row139_col0 {
#   background-color: #f8dbe0;
#   color: #000000;
# }
# #T_117ee_row2_col0 {
#   background-color: #fec5cf;
#   color: #000000;
# }
# #T_117ee_row3_col0, #T_117ee_row11_col0, #T_117ee_row22_col0, #T_117ee_row120_col0, #T_117ee_row124_col0, #T_117ee_row125_col0 {
#   background-color: #fad4db;
#   color: #000000;
# }
# #T_117ee_row4_col0, #T_117ee_row8_col0, #T_117ee_row21_col0, #T_117ee_row38_col0, #T_117ee_row51_col0, #T_117ee_row57_col0, #T_117ee_row88_col0, #T_117ee_row103_col0 {
#   background-color: #fccdd5;
#   color: #000000;
# }
# ...

# %% [markdown]
# # 9) Does rating influences the cost of restaurant?(Boxplot)

# %%
avgcostforindres=indiaRes['Average Cost for two']
aggratingofindres=pd.Categorical(values=indiaRes['Rating text'],categories=["Excellent","Very Good","Good","Average","Poor","Not rated"],ordered=True)
sns.boxplot(x=aggratingofindres,y=avgcostforindres)
# Out:
# <Axes: ylabel='Average Cost for two'>

# %% [markdown]
# #### The plot shows rating does influence cost of restaurant

# %% [markdown]
# # 10) Top Percentage cover of restaurants in a city.(Draw pie graph for this).

# %%
plt.figure(figsize=(10,10))
indiaRes['City'].value_counts().head().plot(kind='pie',autopct="%1.1f%%")
# Out:
# <Axes: ylabel='City'>

# %% [markdown]
# # 11)Top cuisines in Indian restaurants.( Draw pie graph for this)

# %%
IndianCuisines=restaurants[restaurants['Country']=='India']['Cuisines'].value_counts().head()
plt.figure(figsize=(8, 8))
plt.pie(IndianCuisines, labels=IndianCuisines.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Cuisines in Indian Restaurants')
plt.show()
